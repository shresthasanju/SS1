# %% [markdown]
# # Write python function for creating a random oscialltion with amplitude in range (1,5) and frequency in range (0.25,1)
# ## Create 20 different oscillations by implementing python function defined above and implement superposition principle to obtain single resultant oscillation.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
fs = 100
ts = np.arange(0,60,1/fs)   
'''initialize figure'''
plt.figure(figsize = [20,6])
'''iterate over each amplitude and frequency and create a oscillation plot'''
for i in range(1,6):
    amp = 1*float(i)
    freq = 0.0625+0.1875*float(i)          
    '''Y= A sin(wt) | w = 2*pi*f'''
    ys = amp*np.sin(ts*2*np.pi*freq)
    lb= "amp: "+str(amp)[0:4] + ",freq:"+str(freq)[0:4]
    plt.plot(ts,ys,label=lb )
plt.xlabel("Time in seconds") 
plt.ylabel("Displacement")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
fs = 100
ts = np.arange(0,60,1/fs)   #initialize figure
plt.figure(figsize = [20,6]) #iterate over each amplitude and frequency and create a oscillation plot
#xs = np.arange(-10,10,0.01)
#sigmas = [ 1.0,1.5,2.0,2.5,3.0,3.5,4.0]
#mus = [0.0,1.0,1.5,2.0,2.5,3.0,3.5]
#for s,m in zip(sigmas,mus):
# N = 1/np.sqrt(2*np.pi*s**2)
#    fx = N*np.exp(-(xs-m)**2/(2*s**2))
    
#for i in range(1,21):
#    amps = 1*float(i)
#    freqs = 0.0625+0.1875*float(i)
amps=[ 1.0,21.0,1]
freqs=[0.0,10.5,0.5]
for amp,freq in zip(amps,freqs):  
        # Y= A sin(wt) | w = 2*pi*f
        ys = sum([amp*np.sin(ts*2*np.pi*freq) for amp,freq in zip(amps,freqs)])
        #    ys = amp*np.sin(ts*2*np.pi*freq)
        lb= "amp: "+str(amp)[0:4] + ",freq:"+str(freq)[0:4]
plt.plot(ts,ys,label=lb )
plt.xlabel("Time in seconds") 
plt.ylabel("Displacement")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
fs = 100
ts = np.arange(0,60,1/fs)    #initialize figure
plt.figure(figsize = [20,6])  #define 10 different amplitudes and frequencies
#amp = 1*float(i)
#freq = 0.0625+0.1875*float(i)          
amps = [1*1/float(i) for i in range(1,21)]
freqs = [0.0625+0.1875*float(i) for i in range(1,21)]  #List comprehension: '''
ys = sum([amp*np.sin(ts*2*np.pi*freq) for amp,freq in zip(amps,freqs)])

'''create a plot'''
plt.plot(ts,ys, label= "Superposed oscillation")
plt.legend()
plt.show()
